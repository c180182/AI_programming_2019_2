# %% [markdown]
# ## Artificial Neuron（人工ニューロン）

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

from IPython.display import Image, display

# %%
#画像の読み込みと表示
Image("./neuron_1.png")

# %%
#画像の読み込みと表示
Image("./neuron_2.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-e233f91b4514> in <module>
#       1 #画像の読み込みと表示
# ----> 2 Image("./neuron_2.png")
#
# NameError: name 'Image' is not defined

# %% [markdown]
# $y = \begin{cases}
# 1 &  (wx \geq \theta)\\
# 0 & (wx < \theta)
# \end{cases}$
#
#
# #### 出力が１のときにニューロンは信号を出力する＝発火（Fire)するとよぶ
# #### 脳の場合、電流が流れる
# #### 閾値$\theta$を表すために、1という入力を考え、この入力の重みを$\theta$とすることもある

# %% [markdown]
# ## 練習問題
#
# 100点満点のテストのスコアに対して、
#
# 60点以上なら１を返す
#
# 59点以下なら0を返す
#
# という関数を定義して、スコア90点と35点に対して合否判定をするPythonプログラムを記述しなさい。

# %% [markdown]
# ## 単層パーセプトロン
#
# 以下の単層パーセプトロンを使って、様々な演算を実現しよう
#
#
# $y = \begin{cases}
# 1 &  (w_1x_1 + w_2 x_2 \geq \theta)\\
# 0 & (w_1x_1 + w_2 x_2 < \theta)
# \end{cases}$

# %% [markdown]
# ## 練習問題（単層パーセプトロン）
#
# x1, x2に対して以下の結果を返すパーセプトロンをPythonで記述して、
#
# w1（x1に対する重み）、w2（x2に対する重み）とtheta（閾値）の組み合わせを求めなさい。
#
# x1=0, x2=0　ならば　y=0
#
# x1=1, x2=0  ならば　y=0
#
# x1=0, x2=1  ならば　y=0
#
# x1=1, x2=1  ならば　y=1

# %%
def bias_AND(x1, x2):
    x = np.array([x1, x2])
    w = np.array([0.5, 0.5])
    b = -0.7
    # np.sum() ...引数の総和を返す。
    tmp = np.sum(w*x) + b
    if tmp <= 0:
        return 0
    else:
        return 1

# %%
Image("./and.jpg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f07e3142ab66> in <module>
# ----> 1 Image("./and.jpg")
#
# NameError: name 'Image' is not defined

# %% [markdown]
# ### 上の練習問題は単層パーセプトロンでAND回路を生成した

# %% [markdown]
# ## 練習問題：NAND回路
#
# x1, x2に対して以下の結果を返すパーセプトロンをPythonで記述して、
#
# w1（x1に対する重み）、w2（x2に対する重み）とtheta（閾値）の組み合わせを求めなさい。
#
# x1=0, x2=0　ならば　y=1
#
# x1=1, x2=0  ならば　y=1
#
# x1=0, x2=1  ならば　y=1
#
# x1=1, x2=1  ならば　y=0

# %% [markdown]
# ## 練習問題：XOR回路
#
# x1, x2に対して以下の結果を返すパーセプトロンをPythonで記述して、
#
# w1（x1に対する重み）、w2（x2に対する重み）とtheta（閾値）の組み合わせを求めなさい。
#
# x1=0, x2=0　ならば　y=0
#
# x1=1, x2=0  ならば　y=1
#
# x1=0, x2=1  ならば　y=1
#
# x1=1, x2=1  ならば　y=0

# %%
def NAND(x1, x2):
    x = np.array([x1, x2])
    w = np.array([0.5, 0.5])
    b = 0.7
    tmp = np.sum(w*x) + b
    if tmp <= 0:
        return 0
    else:
        return 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-92fd22f18656> in <module>
# ----> 1 Image('./nand.jpg')
#
# NameError: name 'Image' is not defined

# %%
def OR(x1, x2):
    x = np.array([x1, x2])
    w = np.array([0.5, 0.5])
    b = -0.2
    tmp = np.sum(w*x) + b
    if tmp <= 0:
        return 0
    else:
        return 1

# %% [markdown]
# ## XOR回路の例
#
# XOR回路は、
#
# $w_1 + w_2 < \theta$
#
# $w_1 \geq \theta$
#
# $w_2 \geq \theta$
#
# $0 < \theta$
#
# を満たす。しかしながら、これらの式は同時に成立することはない。
#
# 実は、単層パーセプトロンは、XOR回路を実現できない。

# %% [markdown]
# ## OR回路

# %%
Image('./or.jpg')

# %% [markdown]
# ## ニューラルネットワーク
#
# ### パーセプトロンは人間がパラメータを設定した
# ### ニューラルネットワークはパラメータを自動計算する

# %%
Image('./nn_1.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-fd927647604f> in <module>
# ----> 1 Image('./nn_1.jpg')
#
# NameError: name 'Image' is not defined

# %% [markdown]
# ### 活性化関数(activation function)
#
# 活性化関数$h$は、入力$y'$を$y$に変換する。

# %%
Image('./nn_2.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-1503f5220a64> in <module>
# ----> 1 Image('./nn_2.jpg')
#
# NameError: name 'Image' is not defined

# %% [markdown]
# ### 活性化関数の例

# %% [markdown]
# ### ステップ関数（ヘビサイド関数）
#
#
# \begin{eqnarray} h(y') = \begin{cases} 1 & ( y' \geq 0 ) \\ 0 & ( y' \lt 0 ) \end{cases} \end{eqnarray}
#
# ステップ関数は、0か1しか出力できない。

# %%
Image('./nn_3.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-28182b3263c7> in <module>
# ----> 1 Image('./nn_3.jpg')
#
# NameError: name 'Image' is not defined

# %% [markdown]
# ### シグモイド(sigmoid)関数
#
# 従来、活性化関数としてよく使われていたのがシグモイド関数である。シグモイド関数を用いると学習が停滞することがあるので、使われなくなった。
#
# $h(y') = \displaystyle \frac{ 1 }{ 1 + \exp ( -y' )}$

# %%
Image('./nn_4.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-9ba1b20745e5> in <module>
# ----> 1 Image('./nn_4.jpg')
#
# NameError: name 'Image' is not defined

# %% [markdown]
# ### ReLU(Rectified Linear Unit)関数
#
# 現在、活性化関数として最も広く用いられているのは、ReLU関数である。ReLU関数は、学習の停滞が起こりにくく、計算しやすい、という特徴がある。
#
# \begin{eqnarray} h(y') = \begin{cases} y' & ( y' \geq 0 ) \\ 0 & ( y' \lt 0 ) \end{cases} \end{eqnarray}

# %%
Image('./nn_5.jpg')

# %% [markdown]
# ### シグモイド関数を描画する

# %%
def sigmoid(x):
    return 1/(1 + np.exp(-x))

# %%
x = np.arange(-6.0, 6.0, 0.1)

# %%
y = sigmoid(x)

plt.plot(x, y)

# %% [markdown]
# ### ReLU関数を描画する

# %%
def relu(x):
    return np.maximum(0, x)

# %% [markdown]
# ## シグモイド関数を使ってシンプルなニューラルネットワークを構築する

# %%
Image('./nn_2.jpg')

# %% [markdown]
# $X = [0.6, -0,4]$
#
# $w = [0.2, 0.8]$
#
# $w_0 = \theta = -0.2$
#
# #### Sigmoid関数
#
# $input = w_1x_1 + w_2x_2 + \theta$
#
# $output = sigmoid(input)$
